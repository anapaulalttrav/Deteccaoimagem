# %% [markdown]
# <a href="https://colab.research.google.com/github/anapaulalttrav/Deteccaoimagem/blob/main/DETEC%C3%87%C3%83O_IMAGEM_com_opencv_curso_fazer_retangulo_nos_rostos_oficina_14_4_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt


# Carrega o classificador Haar para
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
# Carrega a imagem
ana = cv2.imread('/content/foto.jpg')
gray = cv2.cvtColor(ana, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(ana)

# %%
plt.imshow(gray)

# %%
# Detecta faces
faces = face_cascade.detectMultiScale(gray, 1.1, 5)

# %%
# Desenha retângulos ao redor das faces detectadas
for (x, y, w, h) in faces:
    cv2.rectangle(ana, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
plt.imshow(cv2.cvtColor(ana, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for matplotlib

# %%
# Carrega a imagem
moca = cv2.imread('/content/face2.jpg')
gray1 = cv2.cvtColor(moca, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(moca)

# %%
# Detecta faces
faces = face_cascade.detectMultiScale(gray1, 1.1, 5)

# %%
# Desenha retângulos ao redor das faces detectadas
for (x, y, w, h) in faces:
    cv2.rectangle(moca, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
plt.imshow(cv2.cvtColor(moca, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for matplotlib

# %%
# Exibe a imagem com as faces detectadas
plt.imshow(cv2.cvtColor(moca,cv2.COLOR_BGR2RGB))
plt.title('Detecção de Faces')
plt.show()

# %%
# Carrega a imagem
moca1 = cv2.imread('/content/rostomoca.PNG')
gray2 = cv2.cvtColor(moca1, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(moca1)

# %%
# Detecta faces
faces1 = face_cascade.detectMultiScale(moca1, 1.1, 5)

# %%
# Desenha retângulos ao redor das faces detectadas
for (x, y, w, h) in faces1:
    cv2.rectangle(moca1, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
# Exibe a imagem com as faces detectadas
plt.imshow(cv2.cvtColor(moca1,cv2.COLOR_BGR2RGB))
plt.title('Foto')
plt.show()

# %%
# Carrega a imagem
pessoas = cv2.imread('/content/duaspessoas.avif')
gray = cv2.cvtColor(pessoas, cv2.COLOR_BGR2GRAY)

# %%
# Exibe a imagem com as faces detectadas
plt.imshow(cv2.cvtColor(pessoas,cv2.COLOR_BGR2RGB))
plt.title('Foto_Duas-Pessoas')
plt.show()

# %%
# Detecta faces
faces1 = face_cascade.detectMultiScale(pessoas, 1.1, 5)

# %%
# Desenha retângulos ao redor das faces detectadas
for (x, y, w, h) in faces1:
    cv2.rectangle(pessoas, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
# Exibe a imagem com as faces detectadas
plt.imshow(cv2.cvtColor(pessoas,cv2.COLOR_BGR2RGB))
plt.title('duaspessoas')
plt.show()
